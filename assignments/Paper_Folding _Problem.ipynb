# %%
#Paper folding problem

#Problem 1
# Code to calculate the thickness when the paper is folded 43 times
thickness= 0.00008
folder_thickness=thickness*(2**43)
print(folder_thickness)

#Problem 2
#Convert meters to kilometers and display with two decimal places
print("thickness:{: .2f} kilometers".format(folded_thickness / 10000))

#Problem 3
#Creating using for statement
thickness=0.00008
n_folded=43
folded_thickness=thickness
for i in range (n_folded):
    folded_thickness=folded_thickness*2
print("thickness: {} meters".format(folded_thickness))


#Problem 4
#Comparison of calculation time

#Method 1- With exponentiation operator
import time
thickness = 0.00008 
n_folded = 43 
firstStart = time.time()
folded_thickness = thickness*(2**n_folded)  
firstElapsed_time = time.time()-firstStart
print("Time using exponentiation operator: {}[s]".format(firstElapsed_time))

#Method 2- With for loop
import time
thickness = 0.00008 
n_folded = 43 
secondStart = time.time()
folded_thickness=thickness
for i in range (n_folded):
    folded_thickness=folded_thickness*2
secondElapsed_time = time.time()-secondStart
print("Time using for loop: {}[s]".format(secondElapsed_time))
    
    
#Problem 5
# Saving to a list

thickness=0.00008
n_folded=43
list_folder_thickness=[thickness]
for i in range (n_folded):
    folded_thickness=folded_thickness*2
    list_folder_thickness.append(list_folder_thickness[-1]*2)
print(list_folder_thickness)
print("The length of the list is:",len(list))


#Problem 6
#Displaying a line graph

import matplotlib.pyplot as plt
# %matplotlib inline

# Display the graph. Title and axis label name.
plt.title("Thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(list_folder_thickness)  
plt.show()

#Problem 7
#Customizing graphs
import matplotlib.pyplot as plt
# %matplotlib inline

plt.title("Thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")

axe = plt.axes()
axe.set_facecolor("blue")
plt.plot(list_folder_thickness, linewidth='3', linestyle='dashed', color='black')
plt.show()
# Out:
# 703687441.77664
# thickness: 618970019642690176.00 kilometers
# thickness: 703687441.77664 meters
# Time using exponentiation operator: 0.0[s]
# Time using for loop: 0.0[s]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096, 0.08192, 0.16384, 0.32768, 0.65536, 1.31072, 2.62144, 5.24288, 10.48576, 20.97152, 41.94304, 83.88608, 167.77216, 335.54432, 671.08864, 1342.17728, 2684.35456, 5368.70912, 10737.41824, 21474.83648, 42949.67296, 85899.34592, 171798.69184, 343597.38368, 687194.76736, 1374389.53472, 2748779.06944, 5497558.13888, 10995116.27776, 21990232.55552, 43980465.11104, 87960930.22208, 175921860.44416, 351843720.88832, 703687441.77664]
# The length of the list is: 44
